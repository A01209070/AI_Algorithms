# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd "/content/gdrive/My Drive/1.0 AI Final Project/LSTM with Framework"
# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/1.0 AI Final Project/LSTM with Framework
# 'Confusion Matrix Model 1.png'	'LSTM M1.ipynb'  'Model 1 Accuracy.png'
# 'Data Pre-Processing.ipynb'	 lstm_m2.h5	  x_test.npy
#  dataset_attack.csv		'LSTM M2.ipynb'   x_train.npy
#  dataset_normal.csv		'LSTM M3.ipynb'   y_test.npy
#  lstm_m1.h5			'LSTM M4.ipynb'   y_train.npy

# %% [markdown]
# # Load the Data set
#
#
#
# 1.   Load the training DDoS X dataframe
# 2.   Load the training DDoS Y dataframe
# 3.   Load the testing DDoS X dataframe
# 4.   Load the testing DDoS Y dataframe

# %%
import pandas as pd
import numpy as np

X_train = np.load("x_train.npy")
X_test = np.load("x_test.npy")
Y_train = np.load("y_train.npy", allow_pickle=True)
Y_test = np.load("y_test.npy",  allow_pickle=True)

print("Training Dataset X:\n")
print(X_train.shape)

print("Prediction Training Dataset Y:\n")
print(Y_train.shape)

print("Testing Dataset X:\n")
print(X_test.shape)

print("Testing Dataset Y:\n")
print(Y_test.shape)
# Out:
# Training Dataset X:
#
# (79978, 25, 25)
# Prediction Training Dataset Y:
#
# (79978,)
# Testing Dataset X:
#
# (19995, 25, 25)
# Testing Dataset Y:
#
# (19995,)

# %% [markdown]
# # Reshape the data
#
# LSTMs expect the data to be in an specific format, usually 3D arrays.

# %%
import numpy as np

print("Shape Before")
print("\t Training X: ", X_train.shape)
print("\t Testing X: ", X_test.shape)

X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 25))

X_test = np.array(X_test)
Y_test = np.array(Y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 25))

print("Shape After")
print("\t Training X: ", X_train.shape)
print("\t Testing X: ", X_test.shape)
# Out:
# Shape Before
# 	 Training X:  (79978, 25, 25)
# 	 Testing X:  (19995, 25, 25)
# Shape After
# 	 Training X:  (79978, 25, 25)
# 	 Testing X:  (19995, 25, 25)

# %% [markdown]
# # LSTM Model
#
#
#
# 1.   Import the required modules
# 2.   Setup the model
# 3.   Train the model
# 4.   Compute the accuracy
# 5.   Save the model

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Bidirectional
from keras.utils import plot_model
from keras.utils.np_utils import to_categorical
from keras.utils import np_utils

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix

model = Sequential()

model.add(LSTM(128, activation='tanh', kernel_regularizer='l2', return_sequences = True))
model.add(LSTM(128, activation='tanh', kernel_regularizer='l2', return_sequences = True))
model.add(LSTM(128, activation='tanh', kernel_regularizer='l2'))
model.add(Dense(128, activation = 'relu', kernel_regularizer='l2'))
model.add(Dense(1, activation = 'sigmoid', kernel_regularizer='l2'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
X_train=np.asarray(X_train).astype(np.float32)
Y_train=np.asarray(Y_train).astype(np.float32)

history = model.fit(X_train, Y_train, epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 2500/2500 [==============================] - 219s 85ms/step - loss: 0.6856 - accuracy: 0.9188
# Epoch 2/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1942 - accuracy: 0.9530
# Epoch 3/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.1656 - accuracy: 0.9609
# Epoch 4/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1891 - accuracy: 0.9546
# Epoch 5/50
# 2500/2500 [==============================] - 220s 88ms/step - loss: 0.1498 - accuracy: 0.9620
# Epoch 6/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1406 - accuracy: 0.9661
# Epoch 7/50
# 2500/2500 [==============================] - 214s 85ms/step - loss: 0.1450 - accuracy: 0.9642
# Epoch 8/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1284 - accuracy: 0.9681
# Epoch 9/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1329 - accuracy: 0.9671
# Epoch 10/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.1218 - accuracy: 0.9696
# Epoch 11/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1237 - accuracy: 0.9692
# Epoch 12/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1174 - accuracy: 0.9714
# Epoch 13/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1223 - accuracy: 0.9683
# Epoch 14/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1204 - accuracy: 0.9706
# Epoch 15/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1137 - accuracy: 0.9714
# Epoch 16/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1517 - accuracy: 0.9654
# Epoch 17/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1808 - accuracy: 0.9627
# Epoch 18/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1394 - accuracy: 0.9687
# Epoch 19/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1331 - accuracy: 0.9687
# Epoch 20/50
# 2500/2500 [==============================] - 216s 87ms/step - loss: 0.1334 - accuracy: 0.9694
# Epoch 21/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1208 - accuracy: 0.9719
# Epoch 22/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1136 - accuracy: 0.9744
# Epoch 23/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1087 - accuracy: 0.9749
# Epoch 24/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1094 - accuracy: 0.9739
# Epoch 25/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1142 - accuracy: 0.9745
# Epoch 26/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.1043 - accuracy: 0.9758
# Epoch 27/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1065 - accuracy: 0.9758
# Epoch 28/50
# 2500/2500 [==============================] - 216s 87ms/step - loss: 0.0990 - accuracy: 0.9778
# Epoch 29/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1350 - accuracy: 0.9748
# Epoch 30/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.0942 - accuracy: 0.9794
# Epoch 31/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1001 - accuracy: 0.9774
# Epoch 32/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1206 - accuracy: 0.9738
# Epoch 33/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1020 - accuracy: 0.9793
# Epoch 34/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.0982 - accuracy: 0.9794
# Epoch 35/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.0999 - accuracy: 0.9789
# Epoch 36/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1098 - accuracy: 0.9774
# Epoch 37/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1096 - accuracy: 0.9783
# Epoch 38/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.1009 - accuracy: 0.9795
# Epoch 39/50
# 2500/2500 [==============================] - 218s 87ms/step - loss: 0.0915 - accuracy: 0.9809
# Epoch 40/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.1175 - accuracy: 0.9738
# Epoch 41/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.1105 - accuracy: 0.9763
# Epoch 42/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.1176 - accuracy: 0.9746
# Epoch 43/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.0971 - accuracy: 0.9805
# Epoch 44/50
# 2500/2500 [==============================] - 214s 86ms/step - loss: 0.0952 - accuracy: 0.9803
# Epoch 45/50
# 2500/2500 [==============================] - 216s 86ms/step - loss: 0.0987 - accuracy: 0.9793
# Epoch 46/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.0937 - accuracy: 0.9803
# Epoch 47/50
# 2500/2500 [==============================] - 217s 87ms/step - loss: 0.1034 - accuracy: 0.9786
# Epoch 48/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.0849 - accuracy: 0.9834
# Epoch 49/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.0857 - accuracy: 0.9826
# Epoch 50/50
# 2500/2500 [==============================] - 215s 86ms/step - loss: 0.0980 - accuracy: 0.9796

# %% [markdown]
# # Accuracy & Confusion Matrix

# %%
model_prediction_results = model.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='lower right')
plt.savefig('Model 4 Accuracy.png')
plt.show()

# %%
tp = 0
tn = 0
fp = 0
fn = 0
model_predictions = model_prediction_results.flatten().round()
model_predictions = model_predictions.tolist()
for i in range(len(Y_test)):
  if model_predictions[i]==1 and Y_test[i]==1:
    tp+=1
  elif model_predictions[i]==0 and Y_test[i]==0:
    tn+=1
  elif model_predictions[i]==0 and Y_test[i]==1:
    fp+=1
  elif model_predictions[i]==1 and Y_test[i]==0:
    fn+=1

# %%
import seaborn as sns; sns.set()

acc = (tp + tn)/ (tp + tn + fp + fn)
print("Accuracy: ", acc*100, "\n")

to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map, annot=True, fmt="d")

figure = ax.get_figure()    
figure.savefig('Confusion Matrix Model 4.png', dpi=400)
# Out:
# Accuracy:  98.56464116029007

# %% [markdown]
# # Save the Model

# %%
model.save('lstm_m4.h5')
