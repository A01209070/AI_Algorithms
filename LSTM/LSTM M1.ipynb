# %%
from google.colab import drive
drive.mount("/content/gdrive")
# %cd "/content/gdrive/My Drive/1.0 AI Final Project/LSTM with Framework"
# !ls
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/1.0 AI Final Project/LSTM with Framework
# 'Data Pre-Processing.ipynb'   dataset_normal.csv   x_test.npy	 y_test.npy
#  dataset_attack.csv	     'LSTM M1.ipynb'	   x_train.npy	 y_train.npy

# %% [markdown]
# # Load the Data set
#
#
#
# 1.   Load the training DDoS X dataframe
# 2.   Load the training DDoS Y dataframe
# 3.   Load the testing DDoS X dataframe
# 4.   Load the testing DDoS Y dataframe

# %%
import pandas as pd
import numpy as np

X_train = np.load("x_train.npy")
X_test = np.load("x_test.npy")
Y_train = np.load("y_train.npy", allow_pickle=True)
Y_test = np.load("y_test.npy",  allow_pickle=True)

print("Training Dataset X:\n")
print(X_train.shape)

print("Prediction Training Dataset Y:\n")
print(Y_train.shape)

print("Testing Dataset X:\n")
print(X_test.shape)

print("Testing Dataset Y:\n")
print(Y_test.shape)
# Out:
# Training Dataset X:
#
# (79978, 25, 25)
# Prediction Training Dataset Y:
#
# (79978,)
# Testing Dataset X:
#
# (19995, 25, 25)
# Testing Dataset Y:
#
# (19995,)

# %% [markdown]
# # Reshape the data
#
# LSTMs expect the data to be in an specific format, usually 3D arrays.

# %%
import numpy as np

print("Shape Before")
print("\t Training X: ", X_train.shape)
print("\t Testing X: ", X_test.shape)

X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 25))

X_test = np.array(X_test)
Y_test = np.array(Y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 25))

print("Shape After")
print("\t Training X: ", X_train.shape)
print("\t Testing X: ", X_test.shape)
# Out:
# Shape Before
# 	 Training X:  (79978, 25, 25)
# 	 Testing X:  (19995, 25, 25)
# Shape After
# 	 Training X:  (79978, 25, 25)
# 	 Testing X:  (19995, 25, 25)

# %% [markdown]
# # LSTM Model
#
#
#
# 1.   Import the required modules
# 2.   Setup the model
# 3.   Train the model
# 4.   Compute the accuracy
# 5.   Save the model

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM
from keras.utils import plot_model
from keras.utils.np_utils import to_categorical
from keras.utils import np_utils

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix

model = Sequential()

model.add(LSTM(64, activation='tanh', kernel_regularizer='l2'))
model.add(Dense(128, activation = 'relu', kernel_regularizer='l2'))
model.add(Dense(1, activation = 'sigmoid', kernel_regularizer='l2'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs = 50, verbose = 1)
# Out:
# Epoch 1/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1201 - accuracy: 0.9716
# Epoch 2/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1170 - accuracy: 0.9717
# Epoch 3/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.1115 - accuracy: 0.9726
# Epoch 4/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1166 - accuracy: 0.9713
# Epoch 5/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.1131 - accuracy: 0.9723
# Epoch 6/50
# 2500/2500 [==============================] - 61s 25ms/step - loss: 0.1130 - accuracy: 0.9727
# Epoch 7/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1111 - accuracy: 0.9729
# Epoch 8/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1066 - accuracy: 0.9743
# Epoch 9/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.1083 - accuracy: 0.9744
# Epoch 10/50
# 2500/2500 [==============================] - 56s 22ms/step - loss: 0.1089 - accuracy: 0.9739
# Epoch 11/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1063 - accuracy: 0.9749
# Epoch 12/50
# 2500/2500 [==============================] - 56s 22ms/step - loss: 0.1098 - accuracy: 0.9744
# Epoch 13/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1046 - accuracy: 0.9756
# Epoch 14/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1097 - accuracy: 0.9742
# Epoch 15/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.1061 - accuracy: 0.9753
# Epoch 16/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.1000 - accuracy: 0.9764
# Epoch 17/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.1054 - accuracy: 0.9753
# Epoch 18/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1009 - accuracy: 0.9765
# Epoch 19/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1002 - accuracy: 0.9772
# Epoch 20/50
# 2500/2500 [==============================] - 56s 22ms/step - loss: 0.1027 - accuracy: 0.9762
# Epoch 21/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.0958 - accuracy: 0.9783
# Epoch 22/50
# 2500/2500 [==============================] - 56s 23ms/step - loss: 0.0974 - accuracy: 0.9779
# Epoch 23/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0947 - accuracy: 0.9789
# Epoch 24/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0929 - accuracy: 0.9787
# Epoch 25/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.1036 - accuracy: 0.9781
# Epoch 26/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0913 - accuracy: 0.9810
# Epoch 27/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0969 - accuracy: 0.9782
# Epoch 28/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0925 - accuracy: 0.9792
# Epoch 29/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0922 - accuracy: 0.9795
# Epoch 30/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0963 - accuracy: 0.9788
# Epoch 31/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0953 - accuracy: 0.9795
# Epoch 32/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0945 - accuracy: 0.9796
# Epoch 33/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0893 - accuracy: 0.9809
# Epoch 34/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0906 - accuracy: 0.9809
# Epoch 35/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0956 - accuracy: 0.9792
# Epoch 36/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0906 - accuracy: 0.9808
# Epoch 37/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0901 - accuracy: 0.9805
# Epoch 38/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0872 - accuracy: 0.9821
# Epoch 39/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.0903 - accuracy: 0.9806
# Epoch 40/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.0946 - accuracy: 0.9807
# Epoch 41/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0861 - accuracy: 0.9832
# Epoch 42/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0913 - accuracy: 0.9811
# Epoch 43/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0840 - accuracy: 0.9832
# Epoch 44/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0863 - accuracy: 0.9817
# Epoch 45/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0855 - accuracy: 0.9821
# Epoch 46/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0857 - accuracy: 0.9820
# Epoch 47/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.0805 - accuracy: 0.9835
# Epoch 48/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.0873 - accuracy: 0.9816
# Epoch 49/50
# 2500/2500 [==============================] - 58s 23ms/step - loss: 0.0820 - accuracy: 0.9832
# Epoch 50/50
# 2500/2500 [==============================] - 57s 23ms/step - loss: 0.0843 - accuracy: 0.9831

# %% [markdown]
# # Accuracy & Confusion Matrix

# %%
model_prediction_results = model.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='lower right')
plt.savefig('Model 1 Accuracy.png')
plt.show()

# %%
tp = 0
tn = 0
fp = 0
fn = 0
model_predictions = model_prediction_results.flatten().round()
model_predictions = model_predictions.tolist()
for i in range(len(Y_test)):
  if model_predictions[i]==1 and Y_test[i]==1:
    tp+=1
  elif model_predictions[i]==0 and Y_test[i]==0:
    tn+=1
  elif model_predictions[i]==0 and Y_test[i]==1:
    fp+=1
  elif model_predictions[i]==1 and Y_test[i]==0:
    fn+=1

# %%
acc = (tp + tn)/ (tp + tn + fp + fn)
print("Accuracy: ", acc*100, "\n")

to_heat_map =[[tn,fp],[fn,tp]]
to_heat_map = pd.DataFrame(to_heat_map, index = ["Attack","Normal"],columns = ["Attack","Normal"])
ax = sns.heatmap(to_heat_map, annot=True, fmt="d")

figure = ax.get_figure()    
figure.savefig('Confusion Matrix Model 1.png', dpi=400)
# Out:
# Accuracy:  98.01450362590649

# %% [markdown]
# # Save the Model

# %%
model.save('lstm_m1.h5')
